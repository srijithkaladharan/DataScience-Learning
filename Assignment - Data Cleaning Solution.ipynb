# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_excel('Lending Data.xlsx')
df

#loading data
# Out:
#                           Name of Lending Institution HQ State Rank  \
# 0                                                 NaN      NaN   -1
# 1                               American Express Co.       NY     1
# 2                            First Citizens Banchares      NC     2
# 3                            Wintrust Financial Corp.      IL     3
# 4                                       Zions Bancorp      UT     4
# 5                             Synovus Financial Corp.      GA     5
# 6                                         BB&T Corp.       NC     6
# 7                                          FNB Corp.       PA     7
# 8                         Capital One Financial Corp.      VA     8
# 9                             Fulton Financial Corp.       PA     8
# 10                            Regions Financial Corp.      AL    10
# 11                                       U S Bancorp.      MN    11
# 12                      First Niagara Financial Grp.       NY    11
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 14 columns):
# Name of Lending Institution    96 non-null object
# HQ State                       93 non-null object
# Rank                           94 non-null object
# TA Ratio1                      94 non-null object
# TBL Ratio1                     94 non-null object
# Amount ($1,000)                94 non-null object
# Number                         94 non-null object
# Lender Asset Size              94 non-null object
# Amount ($1,000).1              94 non-null float64
# Number .1                      94 non-null float64
# Unnamed: 10                    0 non-null float64
# Amount ($1,000).2              94 non-null float64
# Number .2                      94 non-null float64
# CC Amount/TA1                  94 non-null object
# dtypes: float64(5), object(9)
# memory usage: 10.7+ KB

# %%
df.columns
# Out:
# Index(['Name of Lending Institution', 'HQ State', 'Rank', 'TA Ratio1',
#        'TBL Ratio1', 'Amount ($1,000)', 'Number ', 'Lender Asset Size',
#        'Amount ($1,000).1', 'Number .1', 'Unnamed: 10', 'Amount ($1,000).2',
#        'Number .2', 'CC Amount/TA1'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Amount ($1,000).1     Number .1  Unnamed: 10  Amount ($1,000).2  \
# count       9.400000e+01  9.400000e+01          0.0       9.400000e+01
# mean        9.919647e+05  1.964819e+05          NaN       2.023422e+06
# std         2.818599e+06  6.639889e+05          NaN       3.679601e+06
# min        -7.000000e+00 -8.000000e+00          NaN      -9.000000e+00
# 25%         1.940850e+04  6.905000e+02          NaN       1.795375e+05
# 50%         1.278210e+05  7.593000e+03          NaN       8.526710e+05
# 75%         5.284680e+05  3.304275e+04          NaN       2.272185e+06
# max         1.631809e+07  3.603088e+06          NaN       2.615439e+07
#
#            Number .2
# count      94.000000
# mean     8425.255319
# std     15008.480842
# min       -10.000000
# 25%       550.000000
# 50%      3344.000000
# 75%     10750.000000
# max    107411.000000

# %% [markdown]
# #Data Cleaning

# %%
del df['Unnamed: 10']

#deleting the column which contains all null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 13 columns):
# Name of Lending Institution    96 non-null object
# HQ State                       93 non-null object
# Rank                           94 non-null object
# TA Ratio1                      94 non-null object
# TBL Ratio1                     94 non-null object
# Amount ($1,000)                94 non-null object
# Number                         94 non-null object
# Lender Asset Size              94 non-null object
# Amount ($1,000).1              94 non-null float64
# Number .1                      94 non-null float64
# Amount ($1,000).2              94 non-null float64
# Number .2                      94 non-null float64
# CC Amount/TA1                  94 non-null object
# dtypes: float64(4), object(9)
# memory usage: 9.9+ KB

# %%
df = df.dropna()

#deleting the null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 93 entries, 1 to 93
# Data columns (total 13 columns):
# Name of Lending Institution    93 non-null object
# HQ State                       93 non-null object
# Rank                           93 non-null object
# TA Ratio1                      93 non-null object
# TBL Ratio1                     93 non-null object
# Amount ($1,000)                93 non-null object
# Number                         93 non-null object
# Lender Asset Size              93 non-null object
# Amount ($1,000).1              93 non-null float64
# Number .1                      93 non-null float64
# Amount ($1,000).2              93 non-null float64
# Number .2                      93 non-null float64
# CC Amount/TA1                  93 non-null object
# dtypes: float64(4), object(9)
# memory usage: 10.2+ KB

# %%
df = df.replace('-', np.nan)

#replacing '-' with NaN

# %%
df = df.fillna(df.mean())

#replace null values with the column mean
