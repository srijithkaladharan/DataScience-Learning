# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.random.rand(10,4), columns=['a','b','c','d'])
df.plot.bar()

# %%
df.plot.barh()

# %%
df.plot.barh(stacked=True)

# %%
df2 = pd.DataFrame({'a': np.random.randn(1000) + 1, 'b': np.random.randn(1000), 'c': np.random.randn(1000) - 1}, 
                   columns=['a','b','c'])

df2.plot.hist(alpha = 0.5)

#adding each value with one and subtract with one in another

# df2.hist() gives separate histograms for each series(columns) 

# df2.plot.hist() gives a single histogram

# max value for alpha is 1

# %%
df3 = pd.DataFrame(np.random.rand(10,5), columns=['A','B','C','D','E'])

df3.plot.box()

# %%
userSpecific = dict(boxes='DarkGreen',whiskers='DarkOrange',medians='DarkBlue',caps='Gray')

df3.plot.box(color=userSpecific)

# %%
df4 = pd.DataFrame(np.random.rand(10,4), columns=['a','b','c','d'])

df4.plot.area()

# %%
df4.plot.area(stacked=False)

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4],[3,4,5,6])
plt.ylabel('Some Y Values')
plt.xlabel('Some X Values')
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16], 'rs')
plt.axis([0,6,0,20])
plt.show()

# %%
#MATPLOTLIB demo

import numpy as np
import matplotlib.pyplot as plt


N = 5
menMeans = (20, 35, 30, 35, 27)
womenMeans = (25, 32, 34, 20, 25)
menStd = (2, 3, 4, 1, 2)
womenStd = (3, 5, 2, 3, 3)
ind = np.arange(N)    # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence

p1 = plt.bar(ind, menMeans, width, yerr=menStd)
p2 = plt.bar(ind, womenMeans, width,
             bottom=menMeans, yerr=womenStd)

plt.ylabel('Scores')
plt.title('Scores by group and gender')
plt.xticks(ind, ('G1', 'G2', 'G3', 'G4', 'G5'))
plt.yticks(np.arange(0, 81, 10))
plt.legend((p1[0], p2[0]), ('Men', 'Women'))

plt.show()
