# %%
import numpy as np
import pandas as pd

# %%
#creating a series

s = pd.Series(['1.0','2000000',-3])
s
# Out:
# 0        1.0
# 1    2000000
# 2         -3
# dtype: object

# %%
s.describe()
# Out:
# count           3
# unique          3
# top       2000000
# freq            1
# dtype: object

# %%
pd.to_numeric(s)
# Out:
# 0          1.0
# 1    2000000.0
# 2         -3.0
# dtype: float64

# %%
#creating another series

s = pd.Series(['apple','1.0','2',-3])
s
# Out:
# 0    apple
# 1      1.0
# 2        2
# 3       -3
# dtype: object

# %%
pd.to_numeric(s)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "apple"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-9660af08f6be> in <module>
# ----> 1 pd.to_numeric(s)
#
# ~\Anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     133             coerce_numeric = False if errors in ('ignore', 'raise') else True
#     134             values = lib.maybe_convert_numeric(values, set(),
# --> 135                                                coerce_numeric=coerce_numeric)
#     136
#     137     except Exception:
#
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ...

# %%
pd.to_numeric(s, errors='ignore')
# Out:
# 0    apple
# 1      1.0
# 2        2
# 3       -3
# dtype: object

# %%
pd.to_numeric(s, errors = 'raise')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "apple"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-f6269e4b554b> in <module>
# ----> 1 pd.to_numeric(s, errors = 'raise')
#
# ~\Anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     133             coerce_numeric = False if errors in ('ignore', 'raise') else True
#     134             values = lib.maybe_convert_numeric(values, set(),
# --> 135                                                coerce_numeric=coerce_numeric)
#     136
#     137     except Exception:
#
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ...

# %%
pd.to_numeric(s, errors = 'coerce')
# Out:
# 0    NaN
# 1    1.0
# 2    2.0
# 3   -3.0
# dtype: float64

# %%
df = pd.read_csv('fraudData.csv')
df
# Out:
#     custID  gender  state  cardholder  balance  numTrans  numIntlTrans  \
# 0        1       1     35         1.0   3000.0         4            14
# 1        2       2      2         1.0      0.0         9             0
# 2        3       2      2         1.0      0.0        27             9
# 3        4       1     15         1.0      NaN        12             0
# 4        5       1     46         1.0      0.0        11            16
# 5        6       2     44         2.0   5546.0        21             0
# 6        7       1      3         NaN      NaN        41             0
# 7        8       1     10         1.0   6016.0        20             3
# 8        9       2     32         1.0   2428.0         4            10
# 9       10       1     23         1.0      0.0        18            56
# 10      11       1     46         NaN   4601.0        54             0
#
#     creditLine  fraudRisk
# 0            2          0
# 1           18          0
# 2           16          0
# ...

# %%
d = {'a':[1,2,1],'b':[1,'apple','bike'],'c':['ds','apple','ball']}
d

# 'd' is a dictionary
# Out:
# {'a': [1, 2, 1], 'b': [1, 'apple', 'bike'], 'c': ['ds', 'apple', 'ball']}

# %%
de = pd.DataFrame(d)
de

# 'de' is a dataframe created out of a dictionary-'d'/
# Out:
#    a      b      c
# 0  1      1     ds
# 1  2  apple  apple
# 2  1   bike   ball

# %%
test = {'a':[1,2,1,3],'b':[1,'apple','bike'],'c':['ds','apple','ball']}
testdf = pd.DataFrame(test)
testdf
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-eadd3a9cf885> in <module>
#       1 test = {'a':[1,2,1,3],'b':[1,'apple','bike'],'c':['ds','apple','ball']}
# ----> 2 testdf = pd.DataFrame(test)
#       3 testdf
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     390                                  dtype=dtype, copy=copy)
#     391         elif isinstance(data, dict):
# --> 392             mgr = init_dict(data, index, columns, dtype=dtype)
#     393         elif isinstance(data, ma.MaskedArray):
#     394             import numpy.ma.mrecords as mrecords
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     210         arrays = [data[k] for k in keys]
#     211
# ...

# %% [markdown]
# # Understanding

# %%
de.apply(pd.Series.value_counts)

#since we cannot use value_counts for a dataframe
#we use .apply() to use the Pandas's Series's attribute for a dataframe
# Out:
#          a    b    c
# 1      2.0  1.0  NaN
# 2      1.0  NaN  NaN
# apple  NaN  1.0  1.0
# ball   NaN  NaN  1.0
# bike   NaN  1.0  NaN
# ds     NaN  NaN  1.0

# %%
de.value_counts

# can not use value_counts for a dataframe
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-c9e7dca95d96> in <module>
# ----> 1 de.value_counts
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
impute_grps = df.pivot_table(values=['creditLine'], index=['gender','cardholder'], aggfunc=np.mean)
impute_grps
# Out:
#                    creditLine
# gender cardholder
# 1      1.0           5.000000
# 2      1.0          18.666667
#        2.0          13.000000

# %%
df.isna()
# Out:
#     custID  gender  state  cardholder  balance  numTrans  numIntlTrans  \
# 0    False   False  False       False    False     False         False
# 1    False   False  False       False    False     False         False
# 2    False   False  False       False    False     False         False
# 3    False   False  False       False     True     False         False
# 4    False   False  False       False    False     False         False
# 5    False   False  False       False    False     False         False
# 6    False   False  False        True     True     False         False
# 7    False   False  False       False    False     False         False
# 8    False   False  False       False    False     False         False
# 9    False   False  False       False    False     False         False
# 10   False   False  False        True    False     False         False
#
#     creditLine  fraudRisk
# 0        False      False
# 1        False      False
# 2        False      False
# ...

# %% [markdown]
# # Dropna - Delete the null Values

# %%
de= {'training':['DS','DS','DL','de'], 'fe':[np.nan,np.nan,2,4],'tool':[np.nan,np.nan,np.nan,4]}
de
# Out:
# {'training': ['DS', 'DS', 'DL', 'de'],
#  'fe': [nan, nan, 2, 4],
#  'tool': [nan, nan, nan, 4]}

# %%
df1 = pd.DataFrame(de)
df1
# Out:
#   training   fe  tool
# 0       DS  NaN   NaN
# 1       DS  NaN   NaN
# 2       DL  2.0   NaN
# 3       de  4.0   4.0

# %%
df1.dropna(axis=1)
# Out:
#   training
# 0       DS
# 1       DS
# 2       DL
# 3       de

# %%
df1.dropna(thresh = 3)

#threshold value = 3
# Out:
#   training   fe  tool
# 3       de  4.0   4.0

# %%
df1.dropna(subset=['training'])
# Out:
#   training   fe  tool
# 0       DS  NaN   NaN
# 1       DS  NaN   NaN
# 2       DL  2.0   NaN
# 3       de  4.0   4.0

# %%
df1.dropna(subset=['fe'])
# Out:
#   training   fe  tool
# 2       DL  2.0   NaN
# 3       de  4.0   4.0

# %%
df['cardholder'].mode()

# prints the mode value of the column - 'cardholder'
# Out:
# 0    1.0
# dtype: float64

# %% [markdown]
# # fillna()

# %%
d1 = df1.fillna(10)
d1
# Out:
#   training    fe  tool
# 0       DS  10.0  10.0
# 1       DS  10.0  10.0
# 2       DL   2.0  10.0
# 3       de   4.0   4.0

# %%
d2 = df1.fillna(df1.mean())
d2
# Out:
#   training   fe  tool
# 0       DS  3.0   4.0
# 1       DS  3.0   4.0
# 2       DL  2.0   4.0
# 3       de  4.0   4.0

# %%
d3 = df1.replace('de',np.nan)
d4 = d3.fillna(d3.mean())
d4

# while we fill/replace the null values with the mean (column-mean), the column with string values is unaffected
# Out:
#   training   fe  tool
# 0       DS  3.0   4.0
# 1       DS  3.0   4.0
# 2       DL  2.0   4.0
# 3      NaN  4.0   4.0

# %%
d5 = df.fillna(df.mode())
d5

############################### DIDNOT WORK- DOUBT!!!!!!
# Out:
#     custID  gender  state  cardholder  balance  numTrans  numIntlTrans  \
# 0        1       1     35         1.0   3000.0         4            14
# 1        2       2      2         1.0      0.0         9             0
# 2        3       2      2         1.0      0.0        27             9
# 3        4       1     15         1.0      NaN        12             0
# 4        5       1     46         1.0      0.0        11            16
# 5        6       2     44         2.0   5546.0        21             0
# 6        7       1      3         NaN      NaN        41             0
# 7        8       1     10         1.0   6016.0        20             3
# 8        9       2     32         1.0   2428.0         4            10
# 9       10       1     23         1.0      0.0        18            56
# 10      11       1     46         NaN   4601.0        54             0
#
#     creditLine  fraudRisk
# 0            2          0
# 1           18          0
# 2           16          0
# ...

# %%
f = df.mode()
f
# Out:
#     custID  gender  state  cardholder  balance  numTrans  numIntlTrans  \
# 0        1     1.0    2.0         1.0      0.0       4.0           0.0
# 1        2     NaN   46.0         NaN      NaN       NaN           NaN
# 2        3     NaN    NaN         NaN      NaN       NaN           NaN
# 3        4     NaN    NaN         NaN      NaN       NaN           NaN
# 4        5     NaN    NaN         NaN      NaN       NaN           NaN
# 5        6     NaN    NaN         NaN      NaN       NaN           NaN
# 6        7     NaN    NaN         NaN      NaN       NaN           NaN
# 7        8     NaN    NaN         NaN      NaN       NaN           NaN
# 8        9     NaN    NaN         NaN      NaN       NaN           NaN
# 9       10     NaN    NaN         NaN      NaN       NaN           NaN
# 10      11     NaN    NaN         NaN      NaN       NaN           NaN
#
#     creditLine  fraudRisk
# 0          5.0        0.0
# 1          NaN        NaN
# 2          NaN        NaN
# ...

# %%
d6 = df.fillna(df.median())
d6
# Out:
#     custID  gender  state  cardholder  balance  numTrans  numIntlTrans  \
# 0        1       1     35         1.0   3000.0         4            14
# 1        2       2      2         1.0      0.0         9             0
# 2        3       2      2         1.0      0.0        27             9
# 3        4       1     15         1.0   2428.0        12             0
# 4        5       1     46         1.0      0.0        11            16
# 5        6       2     44         2.0   5546.0        21             0
# 6        7       1      3         1.0   2428.0        41             0
# 7        8       1     10         1.0   6016.0        20             3
# 8        9       2     32         1.0   2428.0         4            10
# 9       10       1     23         1.0      0.0        18            56
# 10      11       1     46         1.0   4601.0        54             0
#
#     creditLine  fraudRisk
# 0            2          0
# 1           18          0
# 2           16          0
# ...

# %% [markdown]
# # REPLACE

# %%
df1.columns = ['a','b','c'] 
df1

#Renaming the columns
# Out:
#     a    b    c
# 0  DS  NaN  NaN
# 1  DS  NaN  NaN
# 2  DL  2.0  NaN
# 3  de  4.0  4.0

# %%
df.replace(1,'one')
# Out:
#    custID gender  state cardholder  balance  numTrans  numIntlTrans  \
# 0     one    one     35        one   3000.0         4            14
# 1       2      2      2        one      0.0         9             0
# 2       3      2      2        one      0.0        27             9
# 3       4    one     15        one      NaN        12             0
# 4       5    one     46        one      0.0        11            16
# 5       6      2     44          2   5546.0        21             0
# 6       7    one      3        NaN      NaN        41             0
# 7       8    one     10        one   6016.0        20             3
# 8       9      2     32        one   2428.0         4            10
# 9      10    one     23        one      0.0        18            56
# 10     11    one     46        NaN   4601.0        54             0
#
#    creditLine fraudRisk
# 0           2         0
# 1          18         0
# 2          16         0
# 3           5         0
# ...

# %%
df.replace([1,2],['one','two'])

#replaces all 1 with one and 2 with two
# Out:
#    custID gender state cardholder  balance  numTrans  numIntlTrans creditLine  \
# 0     one    one    35        one   3000.0         4            14        two
# 1     two    two   two        one      0.0         9             0         18
# 2       3    two   two        one      0.0        27             9         16
# 3       4    one    15        one      NaN        12             0          5
# 4       5    one    46        one      0.0        11            16          7
# 5       6    two    44        two   5546.0        21             0         13
# 6       7    one     3        NaN      NaN        41             0        one
# 7       8    one    10        one   6016.0        20             3          6
# 8       9    two    32        one   2428.0         4            10         22
# 9      10    one    23        one      0.0        18            56          5
# 10     11    one    46        NaN   4601.0        54             0          4
#
#    fraudRisk
# 0          0
# ...

# %%
df1.rename(columns={'a':'training'})

#selective renaming
# Out:
#   training    b    c
# 0       DS  NaN  NaN
# 1       DS  NaN  NaN
# 2       DL  2.0  NaN
# 3       de  4.0  4.0

# %%
s = pd.Series([1,2,3,2,3,4])

# %%
s.replace(1, method='ffill')
# Out:
# 0    1
# 1    2
# 2    3
# 3    2
# 4    3
# 5    4
# dtype: int64

# %%
d
# Out:
# {'a': [1, 2, 1], 'b': [1, 'apple', 'bike'], 'c': ['ds', 'apple', 'ball']}

# %%
df1.iloc[1,2] = '10$%'
df1
# Out:
#   training   fe  tool
# 0       DS  NaN   NaN
# 1       DS  NaN  10$%
# 2       DL  2.0   NaN
# 3       de  4.0     4

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
# a    4 non-null object
# b    2 non-null float64
# c    2 non-null object
# dtypes: float64(1), object(2)
# memory usage: 176.0+ bytes

# %%
df1
# Out:
#   training   fe  tool
# 0       DS  NaN   NaN
# 1       DS  NaN   NaN
# 2       DL  2.0   NaN
# 3       de  4.0   4.0

# %%
pd.to_numeric(df1['tool'])
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    4.0
# Name: tool, dtype: float64

# %%
d = df1.replace(regex=True, to_replace = '[^0-9]+', value = '')
d
# Out:
#   training   fe tool
# 0           NaN  NaN
# 1           NaN   10
# 2           2.0  NaN
# 3           4.0    4

# %%
d = df1.replace(regex=True, to_replace = '\%', value = '')
d
# Out:
#   training   fe tool
# 0       DS  NaN  NaN
# 1       DS  NaN  10$
# 2       DL  2.0  NaN
# 3       de  4.0    4

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
# training    4 non-null object
# fe          2 non-null float64
# tool        2 non-null object
# dtypes: float64(1), object(2)
# memory usage: 176.0+ bytes

# %%
df1['tools'] = pd.to_numeric(d['tool'], errors='ignore')
df1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "10$"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-53da02782ef2> in <module>
# ----> 1 df1['tools'] = pd.to_numeric(d['tool'], errors='raise')
#       2 df1
#
# ~\Anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     133             coerce_numeric = False if errors in ('ignore', 'raise') else True
#     134             values = lib.maybe_convert_numeric(values, set(),
# --> 135                                                coerce_numeric=coerce_numeric)
#     136
#     137     except Exception:
#
# ...

# %%
df1['tools'] = pd.to_numeric(d['tool'], errors='raise')
df1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "10$"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-53da02782ef2> in <module>
# ----> 1 df1['tools'] = pd.to_numeric(d['tool'], errors='raise')
#       2 df1
#
# ~\Anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     133             coerce_numeric = False if errors in ('ignore', 'raise') else True
#     134             values = lib.maybe_convert_numeric(values, set(),
# --> 135                                                coerce_numeric=coerce_numeric)
#     136
#     137     except Exception:
#
# ...

# %%
df1['tools'] = pd.to_numeric(d['tool'], errors='coerce')
df1
# Out:
#   training   fe  tool  tools
# 0       DS  NaN   NaN    NaN
# 1       DS  NaN  10$%    NaN
# 2       DL  2.0   NaN    NaN
# 3       de  4.0     4    4.0

# %%
df1['tools'] = df1['tools'].fillna(df1['tools'].mean())
df1
# Out:
#   training   fe  tool  tools
# 0       DS  NaN   NaN    4.0
# 1       DS  NaN  10$%    4.0
# 2       DL  2.0   NaN    4.0
# 3       de  4.0     4    4.0

# %%
df1 = df1.replace([1,2],[100,100])
df1
# Out:
#   training     fe  tool  tools
# 0       DS    NaN   NaN    4.0
# 1       DS    NaN  10$%    4.0
# 2       DL  100.0   NaN    4.0
# 3       de    4.0     4    4.0

# %% [markdown]
# # Duplicates Handling

# %%
df1.drop_duplicates()
# Out:
#   training     fe  tool  tools
# 0       DS    NaN   NaN    4.0
# 1       DS    NaN  10$%    4.0
# 2       DL  100.0   NaN    4.0
# 3       de    4.0     4    4.0

# %%
b = {'a':['a','c','b','d']}
bdf = pd.DataFrame(b)
bdf
# Out:
#    a
# 0  a
# 1  c
# 2  b
# 3  d

# %%
bdf.sort_values('a',ascending=True)
# Out:
#    a
# 0  a
# 2  b
# 1  c
# 3  d

# %%
df.sort_values(['state','gender'])
# Out:
#     custID  gender  state  cardholder  balance  numTrans  numIntlTrans  \
# 1        2       2      2         1.0      0.0         9             0
# 2        3       2      2         1.0      0.0        27             9
# 6        7       1      3         NaN      NaN        41             0
# 7        8       1     10         1.0   6016.0        20             3
# 3        4       1     15         1.0      NaN        12             0
# 9       10       1     23         1.0      0.0        18            56
# 8        9       2     32         1.0   2428.0         4            10
# 0        1       1     35         1.0   3000.0         4            14
# 5        6       2     44         2.0   5546.0        21             0
# 4        5       1     46         1.0      0.0        11            16
# 10      11       1     46         NaN   4601.0        54             0
#
#     creditLine  fraudRisk
# 1           18          0
# 2           16          0
# 6            1          0
# ...

# %%
df.sort_values(['gender','state'])
# Out:
#     custID  gender  state  cardholder  balance  numTrans  numIntlTrans  \
# 6        7       1      3         NaN      NaN        41             0
# 7        8       1     10         1.0   6016.0        20             3
# 3        4       1     15         1.0      NaN        12             0
# 9       10       1     23         1.0      0.0        18            56
# 0        1       1     35         1.0   3000.0         4            14
# 4        5       1     46         1.0      0.0        11            16
# 10      11       1     46         NaN   4601.0        54             0
# 1        2       2      2         1.0      0.0         9             0
# 2        3       2      2         1.0      0.0        27             9
# 8        9       2     32         1.0   2428.0         4            10
# 5        6       2     44         2.0   5546.0        21             0
#
#     creditLine  fraudRisk
# 6            1          0
# 7            6          0
# 3            5          0
# ...

# %% [markdown]
# # Joining

# %%
df1
# Out:
#   training     fe  tool  tools
# 0       DS    NaN   NaN    4.0
# 1       DS    NaN  10$%    4.0
# 2       DL  100.0   NaN    4.0
# 3       de    4.0     4    4.0

# %%
df2 = pd.DataFrame({'status':[1,0,'NaN',1]})
df2
# Out:
#   status
# 0      1
# 1      0
# 2    NaN
# 3      1

# %%
df1.append(df2)
# Out:
# C:\Users\smrithkala\Anaconda3\lib\site-packages\pandas\core\frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#       fe status  tool  tools training
# 0    NaN    NaN   NaN    4.0       DS
# 1    NaN    NaN  10$%    4.0       DS
# 2  100.0    NaN   NaN    4.0       DL
# 3    4.0    NaN     4    4.0       de
# 0    NaN      1   NaN    NaN      NaN
# 1    NaN      0   NaN    NaN      NaN
# 2    NaN    NaN   NaN    NaN      NaN
# 3    NaN      1   NaN    NaN      NaN
